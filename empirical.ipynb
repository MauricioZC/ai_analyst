# %% [markdown]
# ### Test

# %% [markdown]
# #### Get 10-K Data

# %%
# Import libraries

from analyzer.edgar_v2 import Stock

# %%
stock = Stock("AAPL")

# %%
data = stock.get_quarterly_facts()
data.head()
# Out:
# end                                                   2015-03-28  \
# fact
# Accounts Payable, Current                           2.315900e+10
# Accounts Receivable, after Allowance for Credit...  1.090500e+10
# Accrued Income Taxes, Noncurrent                             NaN
# Accrued Liabilities, Current                        2.282700e+10
# Accrued Marketing Costs, Current                    1.384000e+09
#
# end                                                   2015-06-27  \
# fact
# Accounts Payable, Current                           2.647400e+10
# Accounts Receivable, after Allowance for Credit...  1.037000e+10
# Accrued Income Taxes, Noncurrent                             NaN
# Accrued Liabilities, Current                        2.272400e+10
# Accrued Marketing Costs, Current                    1.651000e+09
#
# end                                                   2015-12-26  \
# fact
# Accounts Payable, Current                           3.331200e+10
# ...

# %% [markdown]
# ### Mapper

# %%
import json
import pandas as pd

# %%
with open("data/accounts.json", "r") as f:
    d = json.load(f)

print("Loaded JSON data.")
# Out:
# Loaded JSON data.

# %%
df = pd.DataFrame.from_dict(d, orient="index")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df = pd.DataFrame.from_dict(d, orient="index")
#       2 df.head()
#
# NameError: name 'pd' is not defined
